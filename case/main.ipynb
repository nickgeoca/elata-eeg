# %%
# %load_ext autoreload
# %autoreload 2

import lcd, ads1299evm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ads1299evm.create_ads1299_step()
# Out:
# Exported ads1299evm.step

# %%
lcd.create_lcd_step()
# Out:
# Exported lcd.step with PCB (green) and Panel (darkgreen), mount holes, studs, and screen pocket
