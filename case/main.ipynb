# %%
# %load_ext autoreload
# %autoreload 2
import case

# %%
case.main()
# Out:
# Creating stacked case model...
# Successfully loaded and prepared RaspberryPi5.step
# External Case Dimensions (WxDxH): 5.08 x 3.38 x 1.50 inches
# Internal Case Dimensions (WxDxH): 4.93 x 3.23 x 1.42 inches
# Exporting model to eeg_case.step / .stl
